# %% [markdown]
# # Crime data pre-proccessing
#
# ##

# %%
import pandas as pd
import numpy as np

# %%
# read csv

data = pd.read_csv('crimedata_csv_AllNeighbourhoods_2021+2022.csv')

# %%
df = data.copy()

# %%
df
# Out:
#                                                     TYPE  YEAR  MONTH  DAY  \
# 0                             Break and Enter Commercial  2021     11   21
# 1                             Break and Enter Commercial  2021     11   26
# 2                             Break and Enter Commercial  2021     12   14
# 3                             Break and Enter Commercial  2021      7   17
# 4                             Break and Enter Commercial  2021      6   15
# ...                                                  ...   ...    ...  ...
# 35454  Vehicle Collision or Pedestrian Struck (with I...  2022      1    7
# 35455  Vehicle Collision or Pedestrian Struck (with I...  2022      1   18
# 35456  Vehicle Collision or Pedestrian Struck (with I...  2022      2    8
# 35457  Vehicle Collision or Pedestrian Struck (with I...  2022      1    4
# 35458  Vehicle Collision or Pedestrian Struck (with I...  2022      1   17
#
#        HOUR  MINUTE               HUNDRED_BLOCK              NEIGHBOURHOOD  \
# 0         6      33             10XX ALBERNI ST                   West End
# 1        13      58             10XX BARCLAY ST                   West End
# 2         2       2              10XX BEACH AVE  Central Business District
# 3         5       0              10XX BEACH AVE  Central Business District
# 4         4       0              10XX BEACH AVE  Central Business District
# ...     ...     ...                         ...                        ...
# 35454    14       1        W 7TH AVE / ALDER ST                   Fairview
# 35455    20       4  WILLOW ST / W BROADWAY AVE                   Fairview
# 35456    19      52     WINDSOR ST / E 49TH AVE                     Sunset
# 35457    14      56          X BLOCK E 33RD AVE                 Riley Park
# 35458    14      36           X BLOCK E 6TH AVE             Mount Pleasant
#
#                  X            Y
# 0      491015.9434  5459166.140
# 1      490833.8455  5458886.535
# 2      490252.3815  5458162.723
# 3      490255.3982  5458158.788
# 4      490258.4148  5458154.853
# ...            ...          ...
# 35454  490448.0000  5456949.000
# 35455  491136.0000  5456735.000
# 35456  493792.0000  5452516.000
# 35457  492354.0000  5454205.000
# 35458  492400.0000  5456983.000
#
# [35459 rows x 10 columns]

# %%
# find number of unique values

df.nunique()
# Out:
# TYPE                11
# YEAR                 2
# MONTH               12
# DAY                 31
# HOUR                24
# MINUTE              60
# HUNDRED_BLOCK     7901
# NEIGHBOURHOOD       24
# X                15691
# Y                15587
# dtype: int64

# %% [markdown]
# ## Cleaning data

# %%
#  certain crimes like homicides, some of the data is unlabelled in order to respect the privacy of victims. I decided to drop it as

df.isnull().sum()
# Out:
# TYPE             0
# YEAR             0
# MONTH            0
# DAY              0
# HOUR             0
# MINUTE           0
# HUNDRED_BLOCK    0
# NEIGHBOURHOOD    9
# X                2
# Y                2
# dtype: int64

# %%
# creating column with datetime object

dt = df.columns[1:5]
df['datetime'] = pd.to_datetime(df[dt])

# %%
# This is not important, as the recorded time it occurred does not accurately reflect the actual time the crime occurred.
# There is sometimes a slight delay in reporting of the crime

df = df.drop(columns=['MINUTE'])

# %%
# count of types of crime in 2021 and 2022

df[['YEAR', 'TYPE']].groupby(['TYPE']).count()
# Out:
#                                                     YEAR
# TYPE
# Break and Enter Commercial                          2322
# Break and Enter Residential/Other                   1649
# Homicide                                              18
# Mischief                                            5996
# Offence Against a Person                            4117
# Other Theft                                         9595
# Theft from Vehicle                                  8212
# Theft of Bicycle                                    1508
# Theft of Vehicle                                     927
# Vehicle Collision or Pedestrian Struck (with Fa...    21
# Vehicle Collision or Pedestrian Struck (with In...  1092

# %%
df.corr()
# Out:
#            YEAR     MONTH       DAY      HOUR         X         Y
# YEAR   1.000000 -0.434993 -0.065726  0.012041  0.000793  0.000612
# MONTH -0.434993  1.000000  0.024007 -0.002807 -0.001674 -0.001526
# DAY   -0.065726  0.024007  1.000000  0.002580 -0.011597 -0.011679
# HOUR   0.012041 -0.002807  0.002580  1.000000  0.537629  0.537564
# X      0.000793 -0.001674 -0.011597  0.537629  1.000000  0.999877
# Y      0.000612 -0.001526 -0.011679  0.537564  0.999877  1.000000

# %%
# dropping null UTM-coordinates in the X and Y columns

df=df.dropna(subset=['X', 'Y'])

# %%
# the lattitude and longitude in the database are in UTM coordinate system
# In order to create a tableau dashboard, the UTM coordiantes need to be converted to lat/long WGS84 coordinate

# import library
import utm

# this function takes the UTM coordinates in that region and turns them into WGS84 coordinates
def rule(row):
    try:
        lat, long = utm.to_latlon(row["X"], row["Y"], 10, 'N')
    except:
        lat = None
        long = None
        pd.Series({"lat": lat, "long": long})
    return pd.Series({"lat": lat, "long": long})

# %%
# run function

df=df.merge(df.apply(rule, axis=1), left_index=True, right_index=True)

# %%
# export to excel file

df.to_excel('crime_data_preprocessed.xlsx')

# %% [markdown]
# # Thefts from Vehicles Project
#
# For the next part of the project I want to create a map which includes the thefts from vehicles.

# %%
# first I will drop all the other types of crime

df_car_thefts=df[df['TYPE']=='Theft from Vehicle']

# %%
df_car_thefts
# Out:
#                      TYPE  YEAR  MONTH  DAY  HOUR    HUNDRED_BLOCK  \
# 21218  Theft from Vehicle  2021     10   28    17     0X KEEFER ST
# 21219  Theft from Vehicle  2021     12   13    17  10XX ALBERNI ST
# 21220  Theft from Vehicle  2021      2    4    17  10XX ALBERNI ST
# 21221  Theft from Vehicle  2021      2   15    14  10XX ALBERNI ST
# 21222  Theft from Vehicle  2021      4   11    13  10XX ALBERNI ST
# ...                   ...   ...    ...  ...   ...              ...
# 35223  Theft from Vehicle  2022      1   20    16   X E CORDOVA ST
# 35224  Theft from Vehicle  2022      1    3    21      X NK_LOC ST
# 35225  Theft from Vehicle  2022      1   25    21      X NK_LOC ST
# 35226  Theft from Vehicle  2022      2    2    14      X NK_LOC ST
# 35227  Theft from Vehicle  2022      2    5    23      X NK_LOC ST
#
#                    NEIGHBOURHOOD            X            Y  \
# 21218  Central Business District  492410.2511  5458497.396
# 21219                   West End  491050.2906  5459131.648
# 21220                   West End  491051.0856  5459143.808
# 21221                   West End  491058.8169  5459123.086
# 21222                   West End  491058.8169  5459123.086
# ...                          ...          ...          ...
# 35223  Central Business District  492424.9863  5458861.332
# 35224                 Strathcona  492765.9374  5458793.303
# 35225                 Strathcona  492765.9374  5458793.303
# 35226                 Strathcona  492765.9374  5458793.303
# 35227                 Strathcona  492765.9374  5458793.303
#
#                  datetime        lat        long
# 21218 2021-10-28 17:00:00  49.279185 -123.104351
# 21219 2021-12-13 17:00:00  49.284871 -123.123063
# 21220 2021-02-04 17:00:00  49.284981 -123.123053
# 21221 2021-02-15 14:00:00  49.284794 -123.122946
# 21222 2021-04-11 13:00:00  49.284794 -123.122946
# ...                   ...        ...         ...
# 35223 2022-01-20 16:00:00  49.282458 -123.104155
# 35224 2022-01-03 21:00:00  49.281851 -123.099466
# 35225 2022-01-25 21:00:00  49.281851 -123.099466
# 35226 2022-02-02 14:00:00  49.281851 -123.099466
# 35227 2022-02-05 23:00:00  49.281851 -123.099466
#
# [8212 rows x 12 columns]

# %%
# occurences of breakins in 2021 and 2022

df_car_thefts[['NEIGHBOURHOOD', 'TYPE']].groupby(['NEIGHBOURHOOD']).count()
# Out:
#                            TYPE
# NEIGHBOURHOOD
# Arbutus Ridge                86
# Central Business District  2192
# Dunbar-Southlands           100
# Fairview                    400
# Grandview-Woodland          392
# Hastings-Sunrise            404
# Kensington-Cedar Cottage    439
# Kerrisdale                  140
# Killarney                   150
# Kitsilano                   363
# Marpole                     283
# Mount Pleasant              445
# Musqueam                      4
# Oakridge                    108
# Renfrew-Collingwood         398
# Riley Park                  256
# Shaughnessy                 101
# South Cambie                 83
# Stanley Park                 48
# Strathcona                  418
# Sunset                      279
# Victoria-Fraserview         194
# West End                    815
# West Point Grey             114

# %%
# extract weekday from datetime object
# this could be useful as there could be more thefts during certain days

df_car_thefts['weekday']=df_car_thefts['datetime'].dt.day_name()
# Out:
# C:\Users\lazar\AppData\Local\Temp/ipykernel_12516/3503494439.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['weekday']=df['datetime'].dt.day_name()

# %%
# count of breakings during each day
# we can see that breakins happen more often during the weekend and monday and decreases during the week

df_car_thefts[['weekday', 'TYPE']].groupby(['weekday']).count()
# Out:
#            TYPE
# weekday
# Friday     1295
# Monday     1217
# Saturday   1248
# Sunday     1218
# Thursday   1067
# Tuesday    1099
# Wednesday  1068

# %%
# drop columns we don't need

df_car_thefts=df_car_thefts.drop(columns=['TYPE', 'HUNDRED_BLOCK','X','Y', 'datetime'])

# %%
df_car_thefts.to_excel('car_thefts.xlsx')
